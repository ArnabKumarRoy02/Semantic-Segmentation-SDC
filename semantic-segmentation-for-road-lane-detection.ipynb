# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import glob
import tensorflow as tf
import tensorflow.keras.layers as tfl
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# # Displaying images and maskes

# %%
def display_images(data, no_img_mask):
    
    # Load the images from the files
    images = glob.glob('/kaggle/input/lyft-udacity-challenge/'+data+'/'+data+'/CameraRGB/*.png')[:no_img_mask]
    masks = glob.glob('/kaggle/input/lyft-udacity-challenge/'+data+'/'+data+'/CameraSeg/*.png')[:no_img_mask]

    for i in range(len(images)):
        images[i] = cv2.imread(images[i])
        masks[i] = cv2.imread(masks[i], cv2.IMREAD_GRAYSCALE)



    fig, axes = plt.subplots(no_img_mask, 2)

    for i in range(len(images)):
        axes[i][0].imshow(images[i])
        axes[i][1].imshow(masks[i])

    # Show the plot
    plt.show()

# %%
display_images('dataA', 3)

# %%
display_images('dataB', 3)

# %%
display_images('dataC', 3)

# %%
display_images('dataD', 3)

# %%
display_images('dataE', 3)

# %% [markdown]
# # Storing images and mask paths

# %%
images_list = []
masks_list = []
def store_imgs_masks(data):
    images_list.append(glob.glob('/kaggle/input/lyft-udacity-challenge/'+data+'/'+data+'/CameraRGB/*.png'))
    masks_list.append(glob.glob('/kaggle/input/lyft-udacity-challenge/'+data+'/'+data+'/CameraSeg/*.png'))

# %%
store_imgs_masks('dataA')
store_imgs_masks('dataB')
store_imgs_masks('dataC')
store_imgs_masks('dataD')
store_imgs_masks('dataE')

# %% [markdown]
# ## Viewing the list just created

# %%
print(images_list[0][:5],'\n')
print(masks_list[0][:5])
# Out:
# ['/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraRGB/F6-50.png', '/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraRGB/F2-90.png', '/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraRGB/02_00_161.png', '/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraRGB/02_00_090.png', '/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraRGB/02_00_040.png']
#
# ['/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraSeg/F6-50.png', '/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraSeg/F2-90.png', '/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraSeg/02_00_161.png', '/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraSeg/02_00_090.png', '/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraSeg/02_00_040.png']

# %% [markdown]
# # Transforming the list of images and masks into one list for images and one for masks

# %%
def get_one_list(list_of_lists):
    
    one_list = []

    for sublist in list_of_lists:
        one_list.extend(sublist)
    return one_list

# %%
images_list = get_one_list(images_list)
masks_list = get_one_list(masks_list)

# %%
print(images_list[50], '\n')
print(masks_list[50])
# Out:
# /kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraRGB/F62-70.png
#
# /kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraSeg/F62-70.png

# %% [markdown]
# # Transforming the list to tensor

# %%
image_list_ds = tf.data.Dataset.list_files(images_list, shuffle=False)
mask_list_ds = tf.data.Dataset.list_files(masks_list, shuffle=False)

for path in zip(image_list_ds.take(3), mask_list_ds.take(3)):
    print(path)
# Out:
# (<tf.Tensor: shape=(), dtype=string, numpy=b'/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraRGB/02_00_000.png'>, <tf.Tensor: shape=(), dtype=string, numpy=b'/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraSeg/02_00_000.png'>)
# (<tf.Tensor: shape=(), dtype=string, numpy=b'/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraRGB/02_00_001.png'>, <tf.Tensor: shape=(), dtype=string, numpy=b'/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraSeg/02_00_001.png'>)
# (<tf.Tensor: shape=(), dtype=string, numpy=b'/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraRGB/02_00_010.png'>, <tf.Tensor: shape=(), dtype=string, numpy=b'/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraSeg/02_00_010.png'>)

# %% [markdown]
# # Combining images and masks into pairs

# %%
image_filenames = tf.constant(images_list)
masks_filenames = tf.constant(masks_list)
dataset = tf.data.Dataset.from_tensor_slices((image_filenames, masks_filenames))

for image, mask in dataset.take(1):
    print(image)
    print(mask)
# Out:
# tf.Tensor(b'/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraRGB/F6-50.png', shape=(), dtype=string)
# tf.Tensor(b'/kaggle/input/lyft-udacity-challenge/dataA/dataA/CameraSeg/F6-50.png', shape=(), dtype=string)

# %% [markdown]
# # Preprocessing of images and masks

# %%
def process_path(image_path, mask_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=3)
    mask = tf.math.reduce_max(mask, axis=-1, keepdims=True)
    return img, mask

def preprocess(image, mask):
    input_image = tf.image.resize(image, (192, 256), method='nearest')
    input_mask = tf.image.resize(mask, (192, 256), method='nearest')

    return input_image, input_mask

image_ds = dataset.map(process_path)
processed_image_ds = image_ds.map(preprocess)

# %% [markdown]
# # Building UNet V2 architecture
#
# ## Encoder (Downsampling Block)

# %%
def conv_block(inputs=None, n_filters=32, dropout_prob=0, max_pooling=True):
    conv = tfl.Conv2D(n_filters, 3, activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    conv = tfl.Conv2D(n_filters, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    
    if dropout_prob > 0:
        conv = tfl.Dropout(dropout_prob)(conv)
        
    if max_pooling:
        next_layer = tfl.MaxPooling2D(pool_size=(2,2))(conv)
        
    else:
        next_layer = conv
        
    skip_connection = conv
    
    return next_layer, skip_connection

# %%
def conv_block_2(inputs=None, n_filters=32, dropout_prob=0, max_pooling=True):
    layer = tfl.Conv2D(n_filters, 3, padding='same', kernel_initializer='he_normal')(inputs)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.ReLU()(layer)
    layer = tfl.Conv2D(n_filters, 3, padding='same', kernel_initializer='he_normal')(layer)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.ReLU()(layer)
    
    if dropout_prob > 0:
        layer = tfl.Dropout(dropout_prob)(layer)
        
    if max_pooling:
        next_layer = tfl.MaxPooling2D(pool_size=(2,2))(layer)
        
    else:
        next_layer = layer
        
    skip_connection = layer
    
    return next_layer, skip_connection

# %%
def conv_block_3(inputs=None, n_filters=32, dropout_prob=0, max_pooling=True):
    layer = tfl.Conv2D(n_filters, 3, padding='same', kernel_initializer='he_normal')(inputs)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.LeakyReLU()(layer)
    layer = tfl.Conv2D(n_filters, 3, padding='same', kernel_initializer='he_normal')(layer)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.LeakyReLU()(layer)
    
    if dropout_prob > 0:
        layer = tfl.Dropout(dropout_prob)(layer)
        
    if max_pooling:
        next_layer = tfl.MaxPooling2D(pool_size=(2,2))(layer)
        
    else:
        next_layer = layer
        
    skip_connection = layer
    
    return next_layer, skip_connection

# %% [markdown]
# ## Decoder (Upsampling Block)

# %%
def upsampling_block(expansive_input, contractive_input, n_filters=32):
    up = tfl.Conv2DTranspose(n_filters, 3, strides=(2,2), padding='same')(expansive_input)
    merge = tfl.concatenate([up, contractive_input], axis=3)
    conv = tfl.Conv2D(n_filters, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge)
    conv = tfl.Conv2D(n_filters, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    return conv

# %%
def upsampling_block_2(expansive_input, contractive_input, n_filters=32):
    up = tfl.Conv2DTranspose(n_filters, 3, strides=(2,2), padding='same')(expansive_input)
    merge = tfl.concatenate([up, contractive_input], axis=3)
    layer = tfl.Conv2D(n_filters, 3, padding='same', kernel_initializer='he_normal')(merge)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.ReLU()(layer)
    layer = tfl.Conv2D(n_filters, 3, padding='same', kernel_initializer='he_normal')(layer)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.ReLU()(layer)
    return layer

# %%
def upsampling_block_3(expansive_input, contractive_input, n_filters=32):
    up = tfl.Conv2DTranspose(n_filters, 3, strides=(2,2), padding='same')(expansive_input)
    merge = tfl.concatenate([up, contractive_input], axis=3)
    layer = tfl.Conv2D(n_filters, 3, padding='same', kernel_initializer='he_normal')(merge)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.LeakyReLU()(layer)
    layer = tfl.Conv2D(n_filters, 3, padding='same', kernel_initializer='he_normal')(layer)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.LeakyReLU()(layer)
    return layer

# %% [markdown]
# # Building the model

# %%
def unet_model(input_size=(96,128,3), n_filters=32, n_classes = 13):
    inputs = tfl.Input(input_size)
    
    cblock1 = conv_block(inputs, n_filters)
    
    cblock2 = conv_block(cblock1[0], n_filters * 2)
    cblock3 = conv_block(cblock2[0], n_filters * 4)
    cblock4 = conv_block(cblock3[0], n_filters * 8, dropout_prob=0.3)
    
    cblock5 = conv_block(cblock4[0], n_filters * 16, dropout_prob=0.3, max_pooling=False)
    
    ublock6 = upsampling_block(cblock5[0], cblock4[1], n_filters * 8)
    ublock7 = upsampling_block(ublock6, cblock3[1], n_filters * 4)
    ublock8 = upsampling_block(ublock7, cblock2[1], n_filters * 2)
    ublock9 = upsampling_block(ublock8, cblock1[1], n_filters)
    
    conv9 = tfl.Conv2D(n_filters, 3, activation='relu', padding='same', kernel_initializer='he_normal')(ublock9)
    conv10 = tfl.Conv2D(n_classes, 1, padding='same')(conv9)
    
    model = tf.keras.Model(inputs=inputs, outputs=conv10)
    
    return model

# %%
def unet_model2(input_size=(96,128,3), n_filters=32, n_classes = 13):
    inputs = tfl.Input(input_size)
    
    cblock1 = conv_block_2(inputs, n_filters)
    
    cblock2 = conv_block_2(cblock1[0], n_filters * 2)
    cblock3 = conv_block_2(cblock2[0], n_filters * 4)
    cblock4 = conv_block_2(cblock3[0], n_filters * 8, dropout_prob=0.3)
    
    cblock5 = conv_block_2(cblock4[0], n_filters * 16, dropout_prob=0.3, max_pooling=False)
    
    ublock6 = upsampling_block_2(cblock5[0], cblock4[1], n_filters * 8)
    ublock7 = upsampling_block_2(ublock6, cblock3[1], n_filters * 4)
    ublock8 = upsampling_block_2(ublock7, cblock2[1], n_filters * 2)
    ublock9 = upsampling_block_2(ublock8, cblock1[1], n_filters)
    
    layer = tfl.Conv2D(n_filters, 3, padding='same', kernel_initializer='he_normal')(ublock9)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.ReLU()(layer)
    layer = tfl.Conv2D(n_classes, 1, padding='same')(layer)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.ReLU()(layer)
    
    model = tf.keras.Model(inputs=inputs, outputs=layer)
    
    return model

# %%
def unet_model3(input_size=(96,128,3), n_filters=32, n_classes = 13):
    inputs = tfl.Input(input_size)
    
    cblock1 = conv_block_3(inputs, n_filters)
    
    cblock2 = conv_block_3(cblock1[0], n_filters * 2)
    cblock3 = conv_block_3(cblock2[0], n_filters * 4)
    cblock4 = conv_block_3(cblock3[0], n_filters * 8, dropout_prob=0.3)
    
    cblock5 = conv_block_3(cblock4[0], n_filters * 16, dropout_prob=0.3, max_pooling=False)
    
    ublock6 = upsampling_block_3(cblock5[0], cblock4[1], n_filters * 8)
    ublock7 = upsampling_block_3(ublock6, cblock3[1], n_filters * 4)
    ublock8 = upsampling_block_3(ublock7, cblock2[1], n_filters * 2)
    ublock9 = upsampling_block_3(ublock8, cblock1[1], n_filters)
    
    layer = tfl.Conv2D(n_filters, 3, padding='same', kernel_initializer='he_normal')(ublock9)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.LeakyReLU()(layer)
    layer = tfl.Conv2D(n_classes, 1, padding='same')(layer)
    layer = tfl.BatchNormalization(axis=3)(layer,training=True)
    layer = tfl.LeakyReLU()(layer)
    
    model = tf.keras.Model(inputs=inputs, outputs=layer)
    
    return model

# %% [markdown]
# # Defining models

# %%
img_height = 192
img_width = 256
num_channels = 3

unet = unet_model((img_height, img_width, num_channels))
unet2 = unet_model2((img_height, img_width, num_channels))
unet3 = unet_model3((img_height, img_width, num_channels))

# %% [markdown]
# # Model's architecture

# %%
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 192, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 192, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 192, 256, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 96, 128, 32)  0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 96, 128, 64)  18496       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 96, 128, 64)  36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 48, 64, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 48, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 48, 64, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 24, 32, 128)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 24, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 24, 32, 256)  590080      ['conv2d_6[0][0]']
#
#  dropout (Dropout)              (None, 24, 32, 256)  0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 16, 256)  0          ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 12, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 12, 16, 512)  2359808     ['conv2d_8[0][0]']
#
#  dropout_1 (Dropout)            (None, 12, 16, 512)  0           ['conv2d_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 24, 32, 256)  1179904    ['dropout_1[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 24, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'dropout[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 24, 32, 256)  1179904     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 24, 32, 256)  590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 48, 64, 128)  295040     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 48, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 48, 64, 128)  295040      ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 48, 64, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 96, 128, 64)  73792      ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 96, 128, 128  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 96, 128, 64)  73792       ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 96, 128, 64)  36928       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 192, 256, 32  18464      ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 192, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 192, 256, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 192, 256, 32  9248        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 192, 256, 32  9248        ['conv2d_17[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 192, 256, 13  429         ['conv2d_18[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 8,640,141
# Trainable params: 8,640,141
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
unet2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 192, 256, 3  0           []
#                                 )]
#
#  conv2d_20 (Conv2D)             (None, 192, 256, 32  896         ['input_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 192, 256, 32  128        ['conv2d_20[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 192, 256, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 192, 256, 32  9248        ['re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 192, 256, 32  128        ['conv2d_21[0][0]']
#  rmalization)                   )
#
#  re_lu_1 (ReLU)                 (None, 192, 256, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 96, 128, 32)  0          ['re_lu_1[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 96, 128, 64)  18496       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 96, 128, 64)  256        ['conv2d_22[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 96, 128, 64)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 96, 128, 64)  36928       ['re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 96, 128, 64)  256        ['conv2d_23[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 96, 128, 64)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 48, 64, 64)  0           ['re_lu_3[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 48, 64, 128)  73856       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 48, 64, 128)  512        ['conv2d_24[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 48, 64, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 48, 64, 128)  147584      ['re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 48, 64, 128)  512        ['conv2d_25[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 48, 64, 128)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 24, 32, 128)  0          ['re_lu_5[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 24, 32, 256)  295168      ['max_pooling2d_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 24, 32, 256)  1024       ['conv2d_26[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 24, 32, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 24, 32, 256)  590080      ['re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 24, 32, 256)  1024       ['conv2d_27[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 24, 32, 256)  0           ['batch_normalization_7[0][0]']
#
#  dropout_2 (Dropout)            (None, 24, 32, 256)  0           ['re_lu_7[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 12,
0][0]']
#  spose)
#
#  concatenate_8 (Concatenate)    (None, 24, 32, 512)  0           ['conv2d_transpose_8[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 24, 32, 256)  1179904     ['concatenate_8[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 24, 32, 256)  1024       ['conv2d_50[0][0]']
#  ormalization)
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 24, 32, 256)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 24, 32, 256)  590080      ['leaky_re_lu_10[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 24, 32, 256)  1024       ['conv2d_51[0][0]']
#  ormalization)
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 24, 32, 256)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 48, 64, 128)  295040     ['leaky_re_lu_11[0][0]']
#  spose)
#
#  concatenate_9 (Concatenate)    (None, 48, 64, 256)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'leaky_re_lu_5[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 48, 64, 128)  295040      ['concatenate_9[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 48, 64, 128)  512        ['conv2d_52[0][0]']
#  ormalization)
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 48, 64, 128)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 48, 64, 128)  147584      ['leaky_re_lu_12[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 48, 64, 128)  512        ['conv2d_53[0][0]']
#  ormalization)
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 48, 64, 128)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 96, 128, 64)  73792      ['leaky_re_lu_13[0][0]']
#  nspose)
#
#  concatenate_10 (Concatenate)   (None, 96, 128, 128  0           ['conv2d_transpose_10[0][0]',
#                                 )                                 'leaky_re_lu_3[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 96, 128, 64)  73792       ['concatenate_10[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 96, 128, 64)  256        ['conv2d_54[0][0]']
#  ormalization)
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 96, 128, 64)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 96, 128, 64)  36928       ['leaky_re_lu_14[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 96, 128, 64)  256        ['conv2d_55[0][0]']
#  ormalization)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 96, 128, 64)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, 192, 256, 32  18464      ['leaky_re_lu_15[0][0]']
#  nspose)                        )
#
#  concatenate_11 (Concatenate)   (None, 192, 256, 64  0           ['conv2d_transpose_11[0][0]',
#                                 )                                 'leaky_re_lu_1[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 192, 256, 32  18464       ['concatenate_11[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 192, 256, 32  128        ['conv2d_56[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 192, 256, 32  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 192, 256, 32  9248        ['leaky_re_lu_16[0][0]']
#                                 )
#
#  batch_normalization_37 (BatchN  (None, 192, 256, 32  128        ['conv2d_57[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 192, 256, 32  0           ['batch_normalization_37[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 192, 256, 32  9248        ['leaky_re_lu_17[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 192, 256, 32  128        ['conv2d_58[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 192, 256, 32  0           ['batch_normalization_38[0][0]']
#                                 )
#
#  conv2d_59 (Conv2D)             (None, 192, 256, 13  429         ['leaky_re_lu_18[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 192, 256, 13  52         ['conv2d_59[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 192, 256, 13  0           ['batch_normalization_39[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 8,652,097
# Trainable params: 8,646,119
# Non-trainable params: 5,978
# __________________________________________________________________________________________________

# %% [markdown]
# # Compiling models

# %%
unet.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
unet2.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
unet3.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# # Displaying some images

# %%
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

# %%
for image, mask in image_ds.take(1):
    sample_image, sample_mask = image, mask
display([sample_image, sample_mask])

# %%
for image, mask in processed_image_ds.take(1):
    sample_image, sample_mask = image, mask
display([sample_image, sample_mask])

# %% [markdown]
# # Training models

# %%
EPOCHS = 50
BUFFER_SIZE = 1000
BATCH_SIZE = 64
map_dataset = processed_image_ds.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
# Splitting data to training set and val set
num_samples = map_dataset.reduce(0, lambda x, _: x + 1).numpy()
train_dataset = map_dataset.take(int(0.8 * num_samples))
val_dataset = map_dataset.skip(int(0.8 * num_samples))
print(processed_image_ds)
# ReduceLROnPlateau and EarlyStopping callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.1,
                              patience=1, min_lr=1e-6)
early_stop = tf.keras.callbacks.EarlyStopping(patience=2)
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(192, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(192, 256, 1), dtype=tf.uint8, name=None))>

# %%
model_history1 = unet.fit(train_dataset,validation_data=val_dataset, epochs=EPOCHS, callbacks=[reduce_lr,early_stop])
# Out:
# Epoch 1/50
# 2023-08-11 03:13:48.689609: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 63/63 [==============================] - 129s 1s/step - loss: 1.5435 - accuracy: 0.4653 - val_loss: 1.0127 - val_accuracy: 0.7010 - lr: 0.0010
# Epoch 2/50
# 63/63 [==============================] - 86s 1s/step - loss: 0.7444 - accuracy: 0.7641 - val_loss: 0.5856 - val_accuracy: 0.7980 - lr: 0.0010
# Epoch 3/50
# 63/63 [==============================] - 86s 1s/step - loss: 0.4526 - accuracy: 0.8632 - val_loss: 0.3611 - val_accuracy: 0.8913 - lr: 0.0010
# Epoch 4/50
# 63/63 [==============================] - 87s 1s/step - loss: 0.3160 - accuracy: 0.9044 - val_loss: 0.2819 - val_accuracy: 0.9142 - lr: 0.0010
50
# 63/63 [==============================] - 114s 2s/step - loss: 0.1320 - accuracy: 0.9838 - val_loss: 0.1304 - val_accuracy: 0.9835 - lr: 0.0010
# Epoch 27/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.1258 - accuracy: 0.9842 - val_loss: 0.1228 - val_accuracy: 0.9843 - lr: 0.0010
# Epoch 28/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.1203 - accuracy: 0.9845 - val_loss: 0.1168 - val_accuracy: 0.9848 - lr: 0.0010
# Epoch 29/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.1133 - accuracy: 0.9854 - val_loss: 0.1112 - val_accuracy: 0.9853 - lr: 0.0010
# Epoch 30/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.1087 - accuracy: 0.9856 - val_loss: 0.1066 - val_accuracy: 0.9857 - lr: 0.0010
# Epoch 31/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.1041 - accuracy: 0.9859 - val_loss: 0.1048 - val_accuracy: 0.9848 - lr: 0.0010
# Epoch 32/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0998 - accuracy: 0.9861 - val_loss: 0.0998 - val_accuracy: 0.9854 - lr: 0.0010
# Epoch 33/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0979 - accuracy: 0.9858 - val_loss: 0.0971 - val_accuracy: 0.9853 - lr: 0.0010
# Epoch 34/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0925 - accuracy: 0.9865 - val_loss: 0.0908 - val_accuracy: 0.9866 - lr: 0.0010
# Epoch 35/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0893 - accuracy: 0.9867 - val_loss: 0.0883 - val_accuracy: 0.9866 - lr: 0.0010
# Epoch 36/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0848 - accuracy: 0.9873 - val_loss: 0.0850 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 37/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0832 - accuracy: 0.9871 - val_loss: 0.0821 - val_accuracy: 0.9870 - lr: 0.0010
# Epoch 38/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0810 - accuracy: 0.9871 - val_loss: 0.0800 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 39/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0763 - accuracy: 0.9879 - val_loss: 0.0761 - val_accuracy: 0.9877 - lr: 0.0010
# Epoch 40/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0740 - accuracy: 0.9880 - val_loss: 0.0740 - val_accuracy: 0.9880 - lr: 0.0010
# Epoch 41/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0719 - accuracy: 0.9882 - val_loss: 0.0726 - val_accuracy: 0.9874 - lr: 0.0010
# Epoch 42/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0701 - accuracy: 0.9882 - val_loss: 0.0715 - val_accuracy: 0.9874 - lr: 0.0010
# Epoch 43/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0680 - accuracy: 0.9883 - val_loss: 0.0675 - val_accuracy: 0.9882 - lr: 0.0010
# Epoch 44/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0648 - accuracy: 0.9889 - val_loss: 0.0643 - val_accuracy: 0.9889 - lr: 0.0010
# Epoch 45/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0632 - accuracy: 0.9889 - val_loss: 0.0631 - val_accuracy: 0.9887 - lr: 0.0010
# Epoch 46/50
# 63/63 [==============================] - 113s 2s/step - loss: 0.0623 - accuracy: 0.9888 - val_loss: 0.0624 - val_accuracy: 0.9885 - lr: 0.0010
# Epoch 47/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0601 - accuracy: 0.9891 - val_loss: 0.0607 - val_accuracy: 0.9888 - lr: 0.0010
# Epoch 48/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0584 - accuracy: 0.9893 - val_loss: 0.0598 - val_accuracy: 0.9884 - lr: 0.0010
# Epoch 49/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0573 - accuracy: 0.9892 - val_loss: 0.0576 - val_accuracy: 0.9890 - lr: 0.0010
# Epoch 50/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.0549 - accuracy: 0.9897 - val_loss: 0.0551 - val_accuracy: 0.9895 - lr: 0.0010

# %%
model_history3 = unet3.fit(train_dataset,validation_data=val_dataset, epochs=EPOCHS, callbacks=[reduce_lr,early_stop])
# Out:
# Epoch 1/50
# 2023-08-11 05:46:07.382437: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/dropout_4/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 63/63 [==============================] - 132s 2s/step - loss: 1.4002 - accuracy: 0.7809 - val_loss: 1.0775 - val_accuracy: 0.8892 - lr: 0.0010
# Epoch 2/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.9738 - accuracy: 0.9071 - val_loss: 0.8883 - val_accuracy: 0.9193 - lr: 0.0010
# Epoch 3/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.8300 - accuracy: 0.9262 - val_loss: 0.7761 - val_accuracy: 0.9312 - lr: 0.0010
# Epoch 4/50
# 63/63 [==============================] - 117s 2s/step - loss: 0
50
# 63/63 [==============================] - 117s 2s/step - loss: 0.0952 - accuracy: 0.9838 - val_loss: 0.0967 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 35/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.0924 - accuracy: 0.9839 - val_loss: 0.0920 - val_accuracy: 0.9837 - lr: 0.0010
# Epoch 36/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.0963 - accuracy: 0.9819 - val_loss: 0.0971 - val_accuracy: 0.9811 - lr: 0.0010
# Epoch 37/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.0877 - accuracy: 0.9843 - val_loss: 0.0856 - val_accuracy: 0.9851 - lr: 1.0000e-04
# Epoch 38/50
# 63/63 [==============================] - 119s 2s/step - loss: 0.0849 - accuracy: 0.9853 - val_loss: 0.0850 - val_accuracy: 0.9852 - lr: 1.0000e-04
# Epoch 39/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.0838 - accuracy: 0.9856 - val_loss: 0.0836 - val_accuracy: 0.9855 - lr: 1.0000e-04
# Epoch 40/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.0827 - accuracy: 0.9858 - val_loss: 0.0844 - val_accuracy: 0.9853 - lr: 1.0000e-04
# Epoch 41/50
# 63/63 [==============================] - 118s 2s/step - loss: 0.0824 - accuracy: 0.9859 - val_loss: 0.0831 - val_accuracy: 0.9856 - lr: 1.0000e-04
# Epoch 42/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.0816 - accuracy: 0.9861 - val_loss: 0.0828 - val_accuracy: 0.9858 - lr: 1.0000e-04
# Epoch 43/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.0807 - accuracy: 0.9862 - val_loss: 0.0817 - val_accuracy: 0.9858 - lr: 1.0000e-04
# Epoch 44/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.0809 - accuracy: 0.9861 - val_loss: 0.0803 - val_accuracy: 0.9862 - lr: 1.0000e-04
# Epoch 45/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.0798 - accuracy: 0.9864 - val_loss: 0.0811 - val_accuracy: 0.9860 - lr: 1.0000e-05
# Epoch 46/50
# 63/63 [==============================] - 117s 2s/step - loss: 0.0796 - accuracy: 0.9865 - val_loss: 0.0813 - val_accuracy: 0.9861 - lr: 1.0000e-05

# %% [markdown]
# # Function to process the predicted mask

# %%
def create_mask(pred_mask):
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0]

# %% [markdown]
# # Model's Performance

# %%
plt.plot(model_history1.history["accuracy"])
plt.plot(model_history1.history["val_accuracy"])
plt.title('Model 1')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
plt.plot(model_history1.history["loss"])
plt.plot(model_history1.history["val_loss"])
plt.title('Model 1')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
plt.plot(model_history2.history["accuracy"])
plt.plot(model_history2.history["val_accuracy"])
plt.title('Model 2')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
plt.plot(model_history2.history["loss"])
plt.plot(model_history2.history["val_loss"])
plt.title('Model 2')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
plt.plot(model_history3.history["accuracy"])
plt.plot(model_history3.history["val_accuracy"])
plt.title('Model 3')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
plt.plot(model_history3.history["loss"])
plt.plot(model_history3.history["val_loss"])
plt.title('Model 3')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# # Function to show predictions

# %%
def show_predictions(unet = unet, dataset=None, num=1):
    """
    Displays the first image of each of the num batches
    """
    if dataset:
        for image, mask in dataset.take(num):
            pred_mask = unet.predict(image)
            display([image[0], mask[0], create_mask(pred_mask)])
    else:
        display([sample_image, sample_mask,
             create_mask(unet.predict(sample_image[tf.newaxis, ...]))])

# %%
show_predictions(unet3,train_dataset, 6)
# Out:
# 2/2 [==============================] - 7s 16ms/step
# 2/2 [==============================] - 0s 255ms/step
# 2/2 [==============================] - 0s 204ms/step
# 2/2 [==============================] - 0s 195ms/step
# 2/2 [==============================] - 0s 209ms/step
# 2/2 [==============================] - 0s 206ms/step

# %% [markdown]
# # Saving the model

# %%
tf.keras.models.save_model(unet3, '/kaggle/working/model.h5')

# %% [markdown]
# # Download the model

# %%
import zipfile
import os
from IPython.display import FileLink

def zip_dir(directory = os.curdir, file_name = 'model.zip'):
    """
    zip all the files in a directory

    Parameters
    _____
    directory: str
        directory needs to be zipped, defualt is current working directory

    file_name: str
        the name of the zipped file (including .zip), default is 'directory.zip'

    Returns
    _____
    Creates a hyperlink, which can be used to download the zip file)
    """
    os.chdir(directory)
    zip_ref = zipfile.ZipFile(file_name, mode='w')
    for folder, _, files in os.walk(directory):
        for file in files:
            if file_name in file:
                pass
            else:
                zip_ref.write(os.path.join(folder, file))

    return FileLink(file_name)

# %%
zip_dir()
# Out:
# /kaggle/working/model.zip
